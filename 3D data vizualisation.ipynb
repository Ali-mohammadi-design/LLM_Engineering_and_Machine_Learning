# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm #Color_Map

# %% [markdown]
# #  Data viz with 3D chart
# ## minimize $$f(x,y)=\frac {1}{3^{-x^2-y^2}+1}$$
# minimize $$ f(x,y)=\frac{1}{r+1}$$ where $r$ is $3^{-x^2-y^2}$

# %%
def f(x,y):
    r=3**(-x**2-y**2)
    return 1/(r+1)

# %%
f(1,0)
# Out:
# 0.75

# %%
x_4=np.linspace(start=-2, stop=2, num=200)
y_4=np.linspace(start=-2, stop=2, num=200)
x_4,y_4=np.meshgrid(x_4,y_4)

# %%
fig=plt.figure(figsize=[16,12])
ax=fig.gca(projection='3d')
ax.plot_surface(x_4,y_4,f(x_4,y_4), cmap=cm.coolwarm , alpha=0.4)
ax.set_xlabel('x', fontsize=20)
ax.set_ylabel('y', fontsize=20)
ax.set_zlabel('f(x,y)=cost', fontsize=20)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_16864\1145139154.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax=fig.gca(projection='3d')
# Text(0.5, 0, 'f(x,y)=cost')

# %%
fig=plt.figure(figsize=[16,12])
ax=fig.gca(projection='3d')
ax.plot_surface(x_4,y_4,f(x_4,y_4), cmap=cm.PiYG , alpha=0.4)
ax.set_xlabel('x', fontsize=20)
ax.set_ylabel('y', fontsize=20)
ax.set_zlabel('f(x,y)=cost', fontsize=20)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_16864\4144946844.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax=fig.gca(projection='3d')
# Text(0.5, 0, 'f(x,y)=cost')
